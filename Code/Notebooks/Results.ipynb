somdagmm_vc = [[vc_somdagmm_OH_70, vc_somdagmm_OH_75, vc_somdagmm_OH_80, vc_somdagmm_OH_85, vc_somdagmm_OH_90, vc_somdagmm_OH_95],
               [vc_somdagmm_gel_70, vc_somdagmm_gel_75, vc_somdagmm_gel_80, vc_somdagmm_gel_85, vc_somdagmm_gel_90, vc_somdagmm_gel_95],
           [vc_somdagmm_label_70, vc_somdagmm_label_75, vc_somdagmm_label_80, vc_somdagmm_label_85, vc_somdagmm_label_90, vc_somdagmm_label_95],
           [vc_somdagmm_70, vc_somdagmm_75, vc_somdagmm_80, vc_somdagmm_85, vc_somdagmm_90, vc_somdagmm_95]]

# %%
vi_results = [rsrae_vi, dagmm_vi, somdagmm_vi]
vc_results = [rsrae_vc, dagmm_vc, somdagmm_vc]

# %%
ufs_results = [[ci_ufs_70, ci_ufs_75, ci_ufs_80, ci_ufs_85, ci_ufs_90, ci_ufs_95],
                [vc_ufs_70, vc_ufs_75, vc_ufs_80, vc_ufs_85, vc_ufs_90, vc_ufs_95]]

# %%
[vi_ufs_70, vi_ufs_75, vi_ufs_80, vi_ufs_85, vi_ufs_90, vi_ufs_95],
[vi_rsrae_label_70, vi_rsrae_label_75, vi_rsrae_label_80, vi_rsrae_label_85, vi_rsrae_label_90, vi_rsrae_label_95],
# Out:
# ([array([9.44718962e-01, 6.84176394e-01, 7.65305315e-01, 5.38303083e-01,
#          1.06000000e+02, 1.79000000e+02, 3.05900000e+03, 1.28200000e+03]),
#   array([9.42923033e-01, 7.25897103e-01, 7.93472231e-01, 5.29388087e-01,
#          8.70000000e+01, 1.98000000e+02, 3.27100000e+03, 1.07000000e+03]),
#   array([9.42718184e-01, 7.69995677e-01, 8.21671142e-01, 5.29936105e-01,
#          7.30000000e+01, 2.12000000e+02, 3.48900000e+03, 8.52000000e+02]),
#   array([9.41759919e-01, 8.12581064e-01, 8.47097569e-01, 5.24760242e-01,
#          5.60000000e+01, 2.29000000e+02, 3.70300000e+03, 6.38000000e+02]),
#   array([9.40187365e-01, 8.53869434e-01, 8.69727273e-01, 5.13975679e-01,
#          3.60000000e+01, 2.49000000e+02, 3.91400000e+03, 4.27000000e+02]),
#   array([9.39235321e-01, 8.96022482e-01, 8.91008324e-01, 5.06930249e-01,
#          1.80000000e+01, 2.67000000e+02, 4.12700000e+03, 2.14000000e+02])],)

# %%
reg_results = [[ci_reg_70, ci_reg_75, ci_reg_80, ci_reg_85, ci_reg_90, ci_reg_95],
                [vc_reg_70, vc_reg_75, vc_reg_80, vc_reg_85, vc_reg_90, vc_reg_95]]

# %%
label_results = [[ci_rsrae_label_70, ci_rsrae_label_75, ci_rsrae_label_80, ci_rsrae_label_85, ci_rsrae_label_90, ci_rsrae_label_95],
                [vc_rsrae_label_70, vc_rsrae_label_75, vc_rsrae_label_80, vc_rsrae_label_85, vc_rsrae_label_90, vc_rsrae_label_95]]

# %%
import matplotlib.pyplot as plt
threshold = [70, 75, 80, 85, 90, 95]
ci_ufs= []
ci_reg = []
ci_label = []
vc_ufs= []
vc_reg = []
vc_label = []
y = []
for i in range(len(threshold)):
    ci_ufs.append(ufs_results[0][i][2])
    ci_reg.append(reg_results[0][i][2])
    ci_label.append(label_results[0][i][2])
    vc_ufs.append(ufs_results[1][i][2])
    vc_reg.append(reg_results[1][i][2])
    vc_label.append(label_results[1][i][2])
    y.append(threshold[i])
print(oh, gel, label, emb, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23012/3656949013.py in <module>
#      16     vc_label.append(label_results[1][i][2])
#      17     y.append(threshold[i])
# ---> 18 print(oh, gel, label, emb, y)
#
# NameError: name 'oh' is not defined

# %%
plt.plot(y,ci_ufs,  label = "USFSM", linestyle="-")
plt.plot(y,ci_reg, label = "Pseudo label", linestyle="--")
plt.plot(y,ci_label, label = "Label", linestyle="-.")
plt.legend()
plt.title("Feature Selected Cols F1 Score")
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.savefig('CI_fs.png')

# %%
plt.plot(y,vc_ufs,  label = "USFSM", linestyle="-")
plt.plot(y,vc_reg, label = "Pseudo label", linestyle="--")
plt.plot(y,vc_label, label = "Label", linestyle="-.")
plt.legend()
plt.title("Feature Selected Cols F1 Score")
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.savefig('VC_fs.png')

# %% [markdown]
# **SOM Plots**

# %%
import matplotlib.pyplot as plt
threshold = [70, 75, 80, 85, 90, 95]
som_size = [5, 10, 15, 20, 25]
emb = []
oh = []
label = []
gel = []
y = []
for i in range(len(som_size)):
    oh.append(som_vc[0][i][0][4])
    gel.append(som_vc[0][i][1][4])
    label.append(som_vc[0][i][2][4])
    emb.append(som_vc[0][i][3][4])
    y.append(som_size[i])
print(oh, gel, label, emb, y)
# Out:
# [5337.0, 5429.0, 5574.0, 5692.0, 5780.0] [5067.0, 5409.0, 5584.0, 5595.0, 5849.0] [5018.0, 5384.0, 5533.0, 5685.0, 5824.0] [6318.0, 7024.0, 7075.0, 7279.0, 7467.0] [5, 10, 15, 20, 25]

# %% [markdown]
# **True positive**

# %%
plt.plot(y,oh,  label = "One Hot", linestyle="-")
plt.plot(y,gel, label = "GEL", linestyle="--")
plt.plot(y,label, label = "Label", linestyle="-.")
plt.plot(y,emb, label = "Embedding", linestyle=":")
plt.legend()
plt.title("SOM Vehicle Claims True Positive")
plt.xlabel("SOM Size")
plt.ylabel("True Positive")
plt.savefig('SOM_VC_TP.png')

# %%
import matplotlib.pyplot as plt
threshold = [70, 75, 80, 85, 90, 95]
som_size = [5, 10, 15, 20, 25]
emb = []
oh = []
label = []
gel = []
y = []
for i in range(len(som_size)):
    oh.append(som_vc[0][i][0][3])
    gel.append(som_vc[0][i][1][3])
    label.append(som_vc[0][i][2][3])
    emb.append(som_vc[0][i][3][3])
    y.append(som_size[i])
print(oh, gel, label, emb, y)

plt.plot(y,oh,  label = "One Hot", linestyle="-")
plt.plot(y,gel, label = "GEL", linestyle="--")
plt.plot(y,label, label = "Label", linestyle="-.")
plt.plot(y,emb, label = "Embedding", linestyle=":")
plt.legend()
plt.title("F1 Score")
plt.xlabel("SOM Size")
plt.ylabel("F1 Score")
plt.savefig('SOM_VC_F1.png')
# Out:
# [0.5403467085925697, 0.5437747538236962, 0.5491776511988411, 0.5535744918213726, 0.5568534916076675] [0.5302861410664381, 0.5430295265995383, 0.54955026481092, 0.5499601397842068, 0.5594245255310123] [0.5284603343672511, 0.542097992569341, 0.5476499353893173, 0.5533136622929175, 0.5584929915008149] [0.5769001039375151, 0.6032066249502893, 0.605106954371892, 0.6127082720583026, 0.6197134079653869] [5, 10, 15, 20, 25]

# %%
import matplotlib.pyplot as plt
threshold = [70, 75, 80, 85, 90, 95]
som_size = [5, 10, 15, 20, 25]
emb = []
oh = []
label = []
gel = []
y = []
for i in range(len(som_size)):
    oh.append(som_vi[0][i][0][3])
    gel.append(som_vi[0][i][1][3])
    label.append(som_vi[0][i][2][3])
    emb.append(som_vi[0][i][3][3])
    y.append(som_size[i])
print(oh, gel, label, emb, y)

plt.plot(y,oh,  label = "One Hot", linestyle="-")
plt.plot(y,gel, label = "GEL", linestyle="--")
plt.plot(y,label, label = "Label", linestyle="-.")
plt.plot(y,emb, label = "Embedding", linestyle=":")
plt.legend()
plt.title("F1 Score")
plt.xlabel("SOM Size")
plt.ylabel("F1 Score")
plt.savefig('SOM_VI_F1.png')
# Out:
# [0.5144315522739121, 0.5144315522739121, 0.5275185198656628, 0.5387359206585919, 0.5387359206585919] [0.5237793862680198, 0.5144315522739121, 0.5125619854750907, 0.5163011190727337, 0.4994750178833399] [0.5200402526703767, 0.5219098194691982, 0.5368663538597704, 0.5406054874574134, 0.5293880866644843] [0.503214151480983, 0.5088228518774476, 0.5013445846821615, 0.5200402526703767, 0.49199675068805393] [5, 10, 15, 20, 25]

# %%
import matplotlib.pyplot as plt
threshold = [70, 75, 80, 85, 90, 95]
som_size = [5, 10, 15, 20, 25]
emb = []
oh = []
label = []
gel = []
y = []
for i in range(len(som_size)):
    oh.append(som_ci[0][i][0][3])
    gel.append(som_ci[0][i][1][3])
    label.append(som_ci[0][i][2][3])
    emb.append(som_ci[0][i][3][3])
    y.append(som_size[i])
print(oh, gel, label, emb, y)

plt.plot(y,oh,  label = "One Hot", linestyle="-")
plt.plot(y,gel, label = "GEL", linestyle="--")
plt.plot(y,label, label = "Label", linestyle="-.")
plt.plot(y,emb, label = "Embedding", linestyle=":")
plt.legend()
plt.title("F1 Score")
plt.xlabel("SOM Size")
plt.ylabel("F1 Score")
plt.savefig('SOM_CI_F1.png')
# Out:
# [0.47, 0.51, 0.47, 0.53, 0.5] [0.47, 0.47, 0.48, 0.54, 0.52] [0.47, 0.49, 0.5, 0.54, 0.53] [0.53, 0.5, 0.47, 0.49, 0.43] [5, 10, 15, 20, 25]

# %%
threshold = [70, 75, 80, 85, 90, 95]
som_size = [5, 10, 15, 20, 25]
dataset = ['car_insurance', 'vehicle_insurance', 'vehicle_claims']
encoding = ['one hot', 'GEL', 'label', 'embedding']
df = pd.DataFrame()
for d in dataset:
    for e in encoding:
        for i in range(len(som_size)):
            for j in range(len(threshold)):
                if e == 'one hot':
                    code = 0
                if e == 'GEL':
                    code = 1
                if e == 'label':
                    code = 2
                if e == 'embedding':
                    code = 3
                if d == 'car_insurance':
                    p = som_ci[j][i][code][0]
                    r = som_ci[j][i][code][1]
                    f = som_ci[j][i][code][2]
                    a = som_ci[j][i][code][3]
                    tp = som_ci[j][i][code][4]
                    fp = som_ci[j][i][code][5]
                    tn = som_ci[j][i][code][6]
                    fn = som_ci[j][i][code][7]  
                if d == 'vehicle_insurance':
                    p = som_vi[j][i][code][0]
                    r = som_vi[j][i][code][1]
                    f = som_vi[j][i][code][2]
                    a = som_vi[j][i][code][3]
                    tp = som_vi[j][i][code][4]
                    fp = som_vi[j][i][code][5]
                    tn = som_vi[j][i][code][6]
                    fn = som_vi[j][i][code][7]            
                if d == 'vehicle_claims':
                    p = som_vc[j][i][code][0]
                    r = som_vc[j][i][code][1]
                    f = som_vc[j][i][code][2]
                    a = som_vc[j][i][code][3]
                    tp = som_vc[j][i][code][4]
                    fp = som_vc[j][i][code][5]
                    tn = som_vc[j][i][code][6]
                    fn = som_vc[j][i][code][7]
                df = df.append({'dataset': d, 'encoding': e, 'som size': som_size[i], 'Threshold': threshold[j], 
                                'Precision':p, 'Recall': r, 'F1 Score': f, 'AUROC': a,
                                'True Positive':tp,'False Positive': fp, 'True Negative':tn, 'False Negative': fn},
                               ignore_index=True)

# %%
df.to_csv('SOM_results.csv', index=False)

# %%
df['F1 Score'].mean()
# Out:
# 0.7285033783388282

# %% [markdown]
# **Plots**

# %%
df1 = df.groupby(['dataset','encoding']).mean()

# %%
df1.drop(['som size', 'Threshold'], axis=1).round(2).to_csv('SOM_encodings.csv')

# %%
df3 = df.groupby(['dataset','som size']).mean()

# %%
df3.drop(['Threshold'], axis=1).round(2).to_csv('SOM_sizes.csv')

# %%
df2 = df.groupby(['dataset','Threshold']).mean()

# %%
df2.drop(['som size'], axis=1).round(4).to_csv('SOM_Threshold.csv')

# %%
som_f1_score_mean = df3['F1 Score'].values.mean()

# %%
df1
# Out:
#                              som size  Threshold  Precision    Recall  \
# dataset           encoding
# car_insurance     GEL            15.0       82.5   0.727002  0.664111
#                   embedding      15.0       82.5   0.735304  0.676667
#                   label          15.0       82.5   0.729614  0.668111
#                   one hot        15.0       82.5   0.730817  0.670222
# vehicle_claims    GEL            15.0       82.5   0.802004  0.738866
#                   embedding      15.0       82.5   0.818259  0.764203
#                   label          15.0       82.5   0.801851  0.738601
#                   one hot        15.0       82.5   0.802264  0.739263
# vehicle_insurance GEL            15.0       82.5   0.939410  0.830415
#                   embedding      15.0       82.5   0.938731  0.827014
#                   label          15.0       82.5   0.940998  0.833052
#                   one hot        15.0       82.5   0.940419  0.832044
#
# ...

# %%
df2
# Out:
#                              som size  Precision    Recall  F1 Score  \
# dataset           Threshold
# car_insurance     70.0           15.0   0.734500  0.617000  0.615000
#                   75.0           15.0   0.728475  0.631833  0.613809
#                   80.0           15.0   0.727520  0.652667  0.617520
#                   85.0           15.0   0.728459  0.677500  0.621095
#                   90.0           15.0   0.731817  0.706333  0.625896
#                   95.0           15.0   0.733333  0.733333  0.620513
# vehicle_claims    70.0           15.0   0.815752  0.685081  0.694289
#                   75.0           15.0   0.813424  0.712409  0.709634
#                   80.0           15.0   0.810659  0.738550  0.721709
#                   85.0           15.0   0.806641  0.763153  0.728754
#                   90.0           15.0   0.801542  0.783656  0.727566
#                   95.0           15.0   0.788548  0.788548  0.695322
# ...

# %%
df3
# Out:
#                             Threshold  Precision    Recall  F1 Score  \
# dataset           som size
# car_insurance     5.0            82.5   0.729369  0.668333  0.617344
#                   10.0           82.5   0.732703  0.673333  0.622998
#                   15.0           82.5   0.723199  0.657361  0.606016
#                   20.0           82.5   0.734081  0.674583  0.623481
#                   25.0           82.5   0.734068  0.675278  0.625022
# vehicle_claims    5.0            82.5   0.802143  0.738773  0.706093
#                   10.0           82.5   0.805772  0.744771  0.712474
#                   15.0           82.5   0.806255  0.745478  0.713123
#                   20.0           82.5   0.807268  0.747112  0.714803
#                   25.0           82.5   0.809034  0.750031  0.717902
# vehicle_insurance 5.0            82.5   0.939831  0.830559  0.853627
#                   10.0           82.5   0.939391  0.829803  0.852977
# ...

# %%
threshold = [70, 75, 80, 85, 90, 95]
model = ['rsrae', 'dagmm', 'somdagmm']
dataset = ['car_insurance', 'vehicle_insurance', 'vehicle_claims']
encoding = ['one hot', 'GEL', 'label', 'embedding']
df = pd.DataFrame()
for d in dataset:
    for e in range(len(encoding)):
        for i in range(len(model)):
            for j in range(len(threshold)):
                if d == 'car_insurance':
                    p = ci_results[i][e][j][0]
                    r = ci_results[i][e][j][1]
                    f = ci_results[i][e][j][2]
                    a = ci_results[i][e][j][3]
                    tp = ci_results[i][e][j][4]
                    fp = ci_results[i][e][j][5]
                    tn = ci_results[i][e][j][6]
                    fn = ci_results[i][e][j][7]  
                if d == 'vehicle_insurance':
                    p = vi_results[i][e][j][0]
                    r = vi_results[i][e][j][1]
                    f = vi_results[i][e][j][2]
                    a = vi_results[i][e][j][3]
                    tp = vi_results[i][e][j][4]
                    fp = vi_results[i][e][j][5]
                    tn = vi_results[i][e][j][6]
                    fn = vi_results[i][e][j][7]            
                if d == 'vehicle_claims':
                    p = vc_results[i][e][j][0]
                    r = vc_results[i][e][j][1]
                    f = vc_results[i][e][j][2]
                    a = vc_results[i][e][j][3]
                    tp = vc_results[i][e][j][4]
                    fp = vc_results[i][e][j][5]
                    tn = vc_results[i][e][j][6]
                    fn = vc_results[i][e][j][7]
                df = df.append({'dataset': d, 'encoding': encoding[e], 'model': model[i], 'Threshold': threshold[j], 
                                'Precision':p, 'Recall': r, 'F1 Score': f, 'AUROC': a,
                                'True Positive':tp,'False Positive': fp, 'True Negative':tn, 'False Negative': fn},
                               ignore_index=True)

# %%
df
# Out:
#             dataset   encoding     model  Threshold  Precision    Recall  \
# 0     car_insurance    one hot     rsrae       70.0   0.766667  0.640000
# 1     car_insurance    one hot     rsrae       75.0   0.764444  0.663333
# 2     car_insurance    one hot     rsrae       80.0   0.766667  0.693333
# 3     car_insurance    one hot     rsrae       85.0   0.749020  0.690000
# 4     car_insurance    one hot     rsrae       90.0   0.751852  0.720000
# ..              ...        ...       ...        ...        ...       ...
# 211  vehicle_claims  embedding  somdagmm       75.0   0.774181  0.622725
# 212  vehicle_claims  embedding  somdagmm       80.0   0.777698  0.655765
# 213  vehicle_claims  embedding  somdagmm       85.0   0.780703  0.688644
# 214  vehicle_claims  embedding  somdagmm       90.0   0.783913  0.722492
# 215  vehicle_claims  embedding  somdagmm       95.0   0.786758  0.756291
#
#      F1 Score     AUROC  True Positive  False Positive  True Negative  \
# ...

# %%
df.to_csv('DL_results.csv', index=False)

# %%
df1 = df.groupby(['dataset','encoding']).mean()

# %%
df1
# Out:
#                              Threshold  Precision    Recall  F1 Score  \
# dataset           encoding
# car_insurance     GEL             82.5   0.723162  0.635370  0.603288
#                   embedding       82.5   0.728349  0.643148  0.611195
#                   label           82.5   0.733062  0.651296  0.620339
#                   one hot         82.5   0.742156  0.665741  0.635859
# vehicle_claims    GEL             82.5   0.787777  0.686529  0.671166
#                   embedding       82.5   0.788323  0.687617  0.672493
#                   label           82.5   0.791499  0.692176  0.676723
#                   one hot         82.5   0.786829  0.685068  0.669706
# vehicle_insurance GEL             82.5   0.939199  0.786124  0.827894
#                   embedding       82.5   0.937198  0.783050  0.825524
#                   label           82.5   0.939462  0.786629  0.828403
#                   one hot         82.5   0.939900  0.787325  0.828988
#
# ...

# %%
df1.drop(['Threshold'], axis=1).round(2).to_csv('DL_encodings.csv')

# %%
df2 = df.groupby(['dataset','encoding', 'model']).mean()

# %%
df2.drop(['Threshold'], axis=1).round(2).to_csv('DL_model_encodings.csv')

# %%
df3 = df.groupby(['dataset','model']).mean()

# %%
df3.drop(['Threshold'], axis=1).round(2).to_csv('DL_models.csv')

# %%
df3.groupby('dataset').mean()
# Out:
#                    Threshold  Precision    Recall  F1 Score     AUROC  \
# dataset
# car_insurance           82.5   0.731682  0.648889  0.617670  0.496449
# vehicle_claims          82.5   0.788607  0.687847  0.672522  0.500437
# vehicle_insurance       82.5   0.938940  0.785782  0.827702  0.503810
#
#                    True Positive  False Positive  True Negative  \
# dataset
# car_insurance          13.583333       66.416667     181.083333
# vehicle_claims       2989.736111    14027.263889   52366.166667
# vehicle_insurance      51.930556      233.069444    3583.097222
#
#                    False Negative
# dataset
# car_insurance           38.916667
# vehicle_claims       11093.833333
# vehicle_insurance      757.902778

# %%
df4 = df.groupby(['model','encoding']).mean()

# %%
df3
# Out:
#                             Threshold  Precision    Recall  F1 Score  \
# dataset           model
# car_insurance     dagmm          82.5   0.735788  0.655833  0.625481
#                   rsrae          82.5   0.730793  0.647500  0.616243
#                   somdagmm       82.5   0.728466  0.643333  0.611287
# vehicle_claims    dagmm          82.5   0.784860  0.681875  0.666303
#                   rsrae          82.5   0.798608  0.703845  0.689226
#                   somdagmm       82.5   0.782352  0.677822  0.662038
# vehicle_insurance dagmm          82.5   0.937033  0.782804  0.825353
#                   rsrae          82.5   0.941665  0.790027  0.831053
#                   somdagmm       82.5   0.938121  0.784515  0.826700
#
#                                AUROC  True Positive  False Positive  \
# dataset           model
# car_insurance     dagmm     0.505327      14.625000       65.375000
#                   rsrae     0.494673      13.375000       66.625000
# ...

# %%
df4.drop(['Threshold'], axis=1).round(4).to_csv('DL_1.csv')

# %%
dfx = df.groupby(['dataset','Threshold']).mean()

# %%
df5 = df4.groupby('model').mean()

# %%
dfx.round(4).to_csv('DL_1.csv')

# %%
dfx
# Out:
#                              Precision    Recall  F1 Score     AUROC  \
# dataset           Threshold
# car_insurance     70.0        0.730952  0.590000  0.597291  0.495739
#                   75.0        0.733704  0.617222  0.613199  0.500710
#                   80.0        0.731944  0.637778  0.619779  0.497159
#                   85.0        0.731699  0.660556  0.625539  0.496449
#                   90.0        0.729630  0.680000  0.623599  0.491477
#                   95.0        0.732164  0.707778  0.626613  0.497159
# vehicle_claims    70.0        0.786537  0.612604  0.634616  0.495777
#                   75.0        0.787573  0.642814  0.653258  0.497807
#                   80.0        0.788646  0.673281  0.669915  0.500235
#                   85.0        0.789337  0.703323  0.683668  0.502011
#                   90.0        0.789794  0.733081  0.694132  0.503362
#                   95.0        0.789753  0.761982  0.699544  0.503432
# ...

# %%
df6 = df4.groupby('encoding').mean()

# %%
df6
# Out:
#            Threshold  Precision    Recall  F1 Score     AUROC  True Positive  \
# encoding
# GEL             82.5   0.816712  0.702674  0.700783  0.494306    1000.333333
# embedding       82.5   0.817956  0.704605  0.703071  0.493733    1012.944444
# label           82.5   0.821341  0.710034  0.708488  0.504641    1077.203704
# one hot         82.5   0.822962  0.712711  0.711518  0.508249     983.185185
#
#            False Positive  True Negative  False Negative
# encoding
# GEL           4793.666667   18692.000000     3981.666667
# embedding     4781.055556   18704.611111     3969.055556
# label         4716.796296   18769.000000     3904.666667
# one hot       4810.814815   18674.851852     3998.814815

# %%
df5['F1 Score'].values
# Out:
# array([0.70571204, 0.71217399, 0.70000855])

# %%
x = ['SOM','DAGMM', 'RSRAE', 'SOM-DAGMM']
y= [0.70596485849416,0.70571204, 0.71217399, 0.70000855]
plt.ylim([0.68, 0.75])
plt.bar(x, y)
plt.savefig('Models.png')

# %%
plt.ylim([0.70, 0.72])
plt.bar(df6.index, df6['F1 Score'].values)
plt.savefig('encode_1.png')

# %%
from bokeh.io import output_file, show, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.models import Range1d
output_file("Dataset Comparison.html")

datasets = ['car_insurance', 'vehicle_claims', 'vehicle_insurance']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : datasets,
        'SOM'   : [0.6189721 , 0.71287899, 0.85365904],
        'DAGMM'   : [0.62548067, 0.66630254, 0.82535291],
        'RSRAE'   : [0.61624297 , 0.68922553, 0.83105346],
       'SOM-DAGMM':  [ 0.61128696, 0.66203828, 0.82670041]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (dataset, model) for dataset in datasets for model in models ]
counts = sum(zip(data['SOM'], data['DAGMM'], data['RSRAE'], data['SOM-DAGMM']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Datasets across Models ",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.6, 0.9)
show(p)
export_png(p, filename="Dataset Comparison.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Dataset Comparison.png'

# %%
output_file("Encoding Comparison.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : encodings,
        'GEL' : [0.7239421176925753, 0.69152532, 0.7152277,0.69559482],
        'Embedding': [ 0.7373210669626213,  0.70497764,  0.70129391, 0.70294101],
        'Label': [0.7258730662336202, 0.71770002, 0.70658469, 0.70118048 ],
        'One Hot': [0.726877262466497, 0.70864516, 0.72558965,  0.7003179 ]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (encoding, model) for model in models for encoding in encodings  ]

counts = sum(zip(data['GEL'], data['Embedding'], data['Label'], data['One Hot']), ()) # like an hstack
source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Encodings across Models",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.65, 0.76)
show(p)
export_png(p, filename="Encoding Comparison.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Encoding Comparison.png'

# %%
output_file("Model Comparison.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : encodings,
        'GEL' : [0.7239421176925753, 0.69152532, 0.7152277,0.69559482],
        'Embedding': [ 0.7373210669626213,  0.70497764,  0.70129391, 0.70294101],
        'Label': [0.7258730662336202, 0.71770002, 0.70658469, 0.70118048 ],
        'One Hot': [0.726877262466497, 0.70864516, 0.72558965,  0.7003179 ]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (model, encoding) for model in models for encoding in encodings]
counts = sum(zip(data['GEL'], data['Embedding'], data['Label'], data['One Hot']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Models across Encodings",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.05
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.65, 0.76)
show(p)
export_png(p, filename="Model Comparison.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Model Comparison.png'

# %%
output_file("Encodings over dataset Comparison.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
datasets = ['car_insurance', 'vehicle_claims', 'vehicle_insurance']

data = {'dataset' : encodings,
        'car_insurance' : [0.60328781, 0.61119536, 0.62033906, 0.63585857],
        'vehicle_insurance': [0.67116621, 0.67249319, 0.67672339, 0.66970569],
        'vehicle_claims': [ 0.82789383, 0.82552402, 0.82840274, 0.82898844]
        }

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (dataset, encoding)  for encoding in encodings for dataset in datasets  ]
counts = sum(zip(data['car_insurance'], data['vehicle_insurance'], data['vehicle_claims']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Dataset across Encodings",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.05
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.60, 0.9)
show(p)
export_png(p, filename="Encoding over dataset Comparison.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Encoding over dataset Comparison.png'

# %%
output_file("Encodings over dataset Comparison.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
datasets = ['car_insurance', 'vehicle_claims']

data = {'dataset' : encodings,
        'car_insurance' : [0.60328781, 0.61119536, 0.62033906, 0.63585857],
        'vehicle_claims': [0.67116621, 0.67249319, 0.67672339, 0.66970569]
        }

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (dataset, encoding)  for encoding in encodings for dataset in datasets  ]
counts = sum(zip(data['car_insurance'], data['vehicle_claims']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Encodings",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.05
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.58, 0.70)
show(p)
export_png(p, filename="CIVC_encodings.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\CIVC_encodings.png'

# %%
from bokeh.io import output_file, show, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.models import Range1d
output_file("Dataset Comparison.html")

datasets = ['car_insurance', 'vehicle_claims']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : datasets,
        'SOM'   : [0.6189721 , 0.71287899],
        'DAGMM'   : [0.62548067, 0.66630254],
        'RSRAE'   : [0.61624297 , 0.68922553],
       'SOM-DAGMM':  [ 0.61128696, 0.66203828]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (dataset, model) for dataset in datasets for model in models ]
counts = sum(zip(data['SOM'], data['DAGMM'], data['RSRAE'], data['SOM-DAGMM']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="F1 Score - Models ",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.58, 0.75)
show(p)
export_png(p, filename="CIVC_Models.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\CIVC_Models.png'

# %%
output_file("Car Insurance.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : encodings,
        'Embedding': [0.5480,  0.5043,  0.4826, 0.5088],
        'GEL' : [0.5639, 0.5581, 0.5846, 0.5456],
        'Label': [0.5521, 0.5348, 0.5587, 0.5139],
        'One Hot': [0.5769, 0.5516, 0.5812, 0.5292 ]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (model, encoding) for model in models for encoding in encodings]
counts = sum(zip(data['GEL'], data['Embedding'], data['Label'], data['One Hot']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="AUC Scores - Models across encodings",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.05
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.45, 0.60)
show(p)
export_png(p, filename="Car Insurance.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Car Insurance.png'

# %%
from bokeh.io import output_file, show, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.models import Range1d
output_file("Vehicle Insurance.html")

encodings = ['GEL', 'Embedding', 'Label', 'One Hot']
models = ['SOM', 'DAGMM', 'RSRAE', 'SOM-DAGMM']

data = {'dataset' : encodings,
        'Embedding': [0.4846,  0.4763,  0.4803, 0.5089],
        'GEL' : [0.5844, 0.4941, 0.5836, 0.5222],
        'Label': [0.5687, 0.5176, 0.5597, 0.5231],
        'One Hot': [0.5742, 0.5245, 0.5823, 0.5179]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (model, encoding) for model in models for encoding in encodings]
counts = sum(zip(data['GEL'], data['Embedding'], data['Label'], data['One Hot']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), height=250, title="AUC Scores - Models across encodings",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.05
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.y_range = Range1d(0.45, 0.60)
show(p)
export_png(p, filename="Vehicle Insurance.png")
# Out:
# 'C:\\Users\\ajayc\\Desktop\\ajay_chawda\\Code\\Notebooks\\Vehicle Insurance.png'
